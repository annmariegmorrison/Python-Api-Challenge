# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (7.13.0)
# Requirement already satisfied: traitlets>=4.3.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: geojson>=2.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (3.0.4)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (2.6.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.15.2)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (46.1.3.post20200330)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.9)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: tornado>=4.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyzmq>=13 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: terminado>=0.8.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: Send2Trash in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: testpath in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: bleach in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
citydatadataframe = pd.read_csv('../Python-Api-Challenge/output.csv')
citydatadataframe.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0  kruisfontein          53      ZA  1591730426        45 -34.00
# 1           1  saint george           1      US  1591730253        15  37.10
# 2           2        castro         100      BR  1591730183        81 -24.79
# 3           3       mataura          36      NZ  1591730427        86 -46.19
# 4           4   tuktoyaktuk          90      CA  1591730427        70  69.45
#
#       Lng  Max Temp  Wind Speed
# 0   24.73     64.96        5.79
# 1 -113.58     73.40        8.05
# 2  -50.01     69.93        8.16
# 3  168.86     50.00        5.01
# 4 -133.04     46.40        3.36

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps

gmaps.configure(api_key="AIzaSyC_mW52jXqSfApTnjT3nAPO9hQUrjSs9f4")

# %%
# Store latitude and longitude in locations
locations = citydatadataframe[["Lat", "Lng"]]

# Fill NaN values and convert to float
humidity = citydatadataframe["Humidity"]

# Plot Heatmap
fig = gmaps.figure(zoom_level=2, center = (0,0))

# Create Heat Layer
heatlayer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=5)

# Add layer
fig.add_layer(heatlayer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
idealcitydf = citydatadataframe.loc[(citydatadataframe["Max Temp"] > 70) & 
                        (citydatadataframe["Max Temp"] < 80) & (citydatadataframe["Cloudiness"] == 0), :]
idealcitydf = idealcitydf.dropna(how='any')
idealcitydf.reset_index(inplace=True)
del idealcitydf['index']
idealcitydf.head()
# Out:
#    Unnamed: 0                City  Cloudiness Country        Date  Humidity  \
# 0          34         east london           0      ZA  1591730432        33
# 1          74  conceicao da barra           0      BR  1591730439        69
# 2          91             kaniama           0      CD  1591730442        43
# 3         114           karpathos           0      GR  1591730447        88
# 4         165           roebourne           0      AU  1591730456        55
#
#      Lat     Lng  Max Temp  Wind Speed
# 0 -33.02   27.91     73.81       10.09
# 1 -18.59  -39.73     76.84        6.80
# 2  -7.57   24.18     71.26        4.23
# 3  35.51   27.21     71.60        6.93
# 4 -20.78  117.13     70.16        7.61

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = idealcitydf.copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#    Unnamed: 0                City  Cloudiness Country        Date  Humidity  \
# 0          34         east london           0      ZA  1591730432        33
# 1          74  conceicao da barra           0      BR  1591730439        69
# 2          91             kaniama           0      CD  1591730442        43
# 3         114           karpathos           0      GR  1591730447        88
# 4         165           roebourne           0      AU  1591730456        55
#
#      Lat     Lng  Max Temp  Wind Speed Hotel Name
# 0 -33.02   27.91     73.81       10.09
# 1 -18.59  -39.73     76.84        6.80
# 2  -7.57   24.18     71.26        4.23
# 3  35.51   27.21     71.60        6.93
# 4 -20.78  117.13     70.16        7.61

# %%
base_url= "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params= {"radius": 5000, "type": "lodging", "key": g_key}

for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    params["location"]=f'{lat},{lng}'
    city= row["City"]
    print(f"Finding hotel in {city}")
    response=requests.get(base_url, params=params).json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = response["results"][0]["name"]
    except(KeyError, IndexError):
            print("Missing field/result...skipping")
# Out:
# Finding hotel in east london
# Finding hotel in conceicao da barra
# Finding hotel in kaniama
# Missing field/result...skipping
# Finding hotel in karpathos
# Finding hotel in roebourne
# Finding hotel in port alfred
# Finding hotel in vila velha
# Finding hotel in akdepe
# Finding hotel in turkistan
# Missing field/result...skipping
# Finding hotel in sadovoye
# Finding hotel in padang
# Finding hotel in agadir
# Finding hotel in uruzgan
# Missing field/result...skipping
# Finding hotel in koutsouras
# Finding hotel in baglan
# Finding hotel in kikwit
# Finding hotel in koson
# Missing field/result...skipping
# Finding hotel in chake chake
# Finding hotel in usinsk

# %%
hotel_df['Hotel Name']=hotel_df['Hotel Name'].replace('',np.nan)
hotel_df.dropna(inplace=True)
hotel_df
# Out:
#     Unnamed: 0                City  Cloudiness Country        Date  Humidity  \
# 0           34         east london           0      ZA  1591730432        33
# 1           74  conceicao da barra           0      BR  1591730439        69
# 3          114           karpathos           0      GR  1591730447        88
# 4          165           roebourne           0      AU  1591730456        55
# 5          180         port alfred           0      ZA  1591730461        37
# 6          247          vila velha           0      BR  1591730475        78
# 7          256              akdepe           0      TM  1591730477        38
# 9          303            sadovoye           0      RU  1591730487        31
# 10         350              padang           0      ID  1591730496        71
# 11         357              agadir           0      MA  1591730497        60
# 13         397          koutsouras           0      GR  1591730505        82
# 14         421              baglan           0      AF  1591730510        30
# 15         454              kikwit           0      CD  1591730515        63
# 17         515         chake chake           0      TZ  1591730527        81
# 18         525              usinsk           0      RU  1591730529        47
#
#       Lat     Lng  Max Temp  Wind Speed                   Hotel Name
# 0  -33.02   27.91     73.81       10.09                      Tu Casa
# 1  -18.59  -39.73     76.84        6.80          Cricaré Praia Hotel
# 3   35.51   27.21     71.60        6.93                         Alex
# 4  -20.78  117.13     70.16        7.61   Harding River Caravan Park
# 5  -33.59   26.89     73.00        5.99           The Halyards Hotel
# 6  -20.33  -40.29     78.01        6.93         Hotel Vitória Palace
# 7   42.06   59.38     73.40        6.93                      Мой дом
# 9   47.78   44.51     78.39        7.74                       Putnik
# 10  -0.95  100.35     78.21        3.89               Mercure Padang
# 11  30.42   -9.60     73.40       20.80       Iberostar Founty Beach
# 13  35.03   25.95     73.00        4.00             The White Houses
# 14  36.13   68.71     76.96        1.68           Habibullah MOsazai
# 15  -5.04   18.82     77.67        1.34  Centre D'Accueil Protestant
# 17  -5.25   39.77     76.15        9.51            Hotel Archipelago
# 18  65.99   57.53     73.49       19.06            Dobro Pozhalovaty

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

markerlayer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markerlayer)


# Display figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
